# %%
from __future__ import division
# %matplotlib inline
import matplotlib as mpl, numpy as np, pandas as pd, seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Basic Fourier Series

# %%
def a(n):
    return 0
def b(n):
    if n == 0:
        return 0
    else:
        return -(2/(n*np.pi))*(np.cos(n*np.pi/2) - 1)
def plotseries(n):
    x = np.linspace(-4,4,1000)
    y = np.zeros_like(x)
    for i in range(0,n+1):
        if i == 0:
            y = y + (1/2)*a(0)
        else:
            y = y + a(i)*np.cos(i*np.pi*x)
            y = y + b(i)*np.sin(i*np.pi*x)
    plt.plot(x,y)

# %%
plotseries(50)

# %%
def a(n):
    if n == 0:
        return 1
    else:
        return (2/(n*np.pi))*np.sin(n*np.pi/2)
def b(n):
    if n == 0:
        return 0
    else:
        return 0
def plotseries(n):
    x = np.linspace(-4,4,1000)
    y = np.zeros_like(x)
    for i in range(0,n+1):
        if i == 0:
            y = y + (1/2)*a(0)
        else:
            y = y + a(i)*np.cos(i*np.pi*x)
            y = y + b(i)*np.sin(i*np.pi*x)
    plt.plot(x,y)

# %%
plotseries(40)
