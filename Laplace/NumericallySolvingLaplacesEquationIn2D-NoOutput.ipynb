# %% [markdown]
# #Numerically solving Laplace's equation
#
# ## Set up and solve once
#
# We discussed in class the idea that the Laplacian ($\nabla^2$) is often referred to as "the averaging operator."[1] We'll put that idea into practice to solve Laplace's equation numerically. We'll do this to solve Laplace's equation ($\nabla^2u=0$) in 2D. We'll do a few things in the code, but the heart of the idea is that we'll divide our system up into a grid, specify the temperature on the boundaries, and then iteratively set each internal point to the average of the surrounding points.
#
# I'll use `imshow` in the main code, but [ipython blocks](https://github.com/jiffyclub/ipythonblocks) makes for nice pretty pictures as a setup.
#
# [1]There are two quick ways to see this. The first is to take the limit definition of the 2nd derivative (noting that you're specifically applying it to functions where limits commute). The second is to take a Taylor expansions and add them together.

# %%
# %matplotlib inline
from ipythonblocks import BlockGrid
import numpy as np, matplotlib.pyplot as plt
from __future__ import division

# %% [markdown]
# Let's start with a 20x20 grid

# %%
grid = BlockGrid(20,20)
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4e7d2225-c7f9-4a16-a416-540a27f9809d td {border: 1px solid white;}</style><table id="blocks4e7d2225-c7f9-4a16-a416-540a27f9809d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 11]&#10;Color: (0, 0 ...

# %% [markdown]
# And set the boundary conditions. In particular, let's say the left edge is set at 200, and the other edges are set at 0. We'll let temperature be represented by the "red" part of an RGB value. That means we can set `block.red` to any number between `0` and `255`.
#
# We'll start with the whole grid at 0 except for the boundary in question.

# %%
for block in grid:
    if block.col == 0:
        block.red = 200
    else:
        block.red = 0
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks209b06b2-ab69-4bee-a78a-bdf2325c006b td {border: 1px solid white;}</style><table id="blocks209b06b2-ab69-4bee-a78a-bdf2325c006b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 11]&#10;Colo ...

# %% [markdown]
# Now, for each round of updating (think of passing the pie in class), we want to iterate over all of the internal blocks, setting their red value equal to the average of their neighbors. By "neighbor," let's say we mean the 4 blocks immediately above, below, left and right.
#
# Our boundary conditions are pretty easy to enforce: if we're in the left or right column (numbered 0 and 19, because Python starts counting from zero), or in the top or bottom row (again, numbered 0 and 19), don't do a thing.

# %%
for block in grid:
    if block.col in (0,19) or block.row in (0,19):
        continue
    block.red = (grid[block.row-1,block.col].red + grid[block.row+1,block.col].red +\
                 grid[block.row,block.col-1].red + grid[block.row,block.col+1].red) / 4.0
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4cda7506-1c5d-401a-a7fe-a63a27042461 td {border: 1px solid white;}</style><table id="blocks4cda7506-1c5d-401a-a7fe-a63a27042461" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (50, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(50, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (13, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(13, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (3, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(3, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (1, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(1, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 11]&#10; ...

# %% [markdown]
# If you look closely, you can indeed see that the second row has some red in it. Remember, this is an approximation method. That means we need to run it over and over until it converges. We'll worry about convergence later; for now, let's wrap it up in a function and run it 10 times:

# %%
def one_step():
    for block in grid:
        if block.col in (0,19) or block.row in (0,19):
            continue
        block.red = (grid[block.row-1,block.col].red + grid[block.row+1,block.col].red +\
                     grid[block.row,block.col-1].red + grid[block.row,block.col+1].red) / 4.0
for i in range(10):
    one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks56a1152e-ecc2-480e-977f-7da60aeddb2b td {border: 1px solid white;}</style><table id="blocks56a1152e-ecc2-480e-977f-7da60aeddb2b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (94, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(94, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (50, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(50, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (28, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(28, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (16, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(16, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (9, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(9, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (5, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(5, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (3, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(3, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (2, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(2, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (1, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(1, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 11]& ...

# %% [markdown]
# We can eyeball our results to see if they've converged by just running it longer:

# %%
for i in range(500):
    one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfbd39865-a7e0-453b-865b-1073a1884f0a td {border: 1px solid white;}</style><table id="blocksfbd39865-a7e0-453b-865b-1073a1884f0a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (99, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(99, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (59, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(59, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (40, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(40, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (29, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(29, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (22, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(22, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (17, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(17, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (14, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(14, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (11, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(11, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (9, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(9, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (7, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(7, 0, 0);"></td><td title="Index:  ...

# %% [markdown]
# And that's really all we need to do to solve Laplace's equation numerically.
#
# ## Different boundary conditions
# Wonder what it looks like with the top and bottom sides set to 200 instead? Just change the boundary conditions and run it again:

# %%
for block in grid:
    if block.row in (0,19):
        block.red = 200
    else:
        block.red = 0
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks38b48b87-8486-46c3-ba53-d63be32e9f37 td {border: 1px solid white;}</style><table id="blocks38b48b87-8486-46c3-ba53-d63be32e9f37" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px; ...

# %%
for i in range(500):
    one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks80a107a8-cc0a-45a6-b21f-7864d6617f1e td {border: 1px solid white;}</style><table id="blocks80a107a8-cc0a-45a6-b21f-7864d6617f1e" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (100, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(100, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (139, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(139, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (157, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(157, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (167, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(167, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (173, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(173, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (177, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(177, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (179, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(179, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (180, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(180, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (181, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(181, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (181, 0, ...

# %% [markdown]
# ## Initial conditions
#
# We know from class that, while the boundary conditions matter, the initial state shouldn't matter at all; the steady-state solution doesn't care. Let's see that by initializing to *random* values from 0 to 255. This is done with np.random.randint(0,256):

# %%
for block in grid:
    if block.row in (0,19):
        block.red = 200
    elif block.col in (0,19):
        block.red = 0
    else:
        block.red = np.random.randint(0,255)
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb3843c74-ad10-4f63-a305-364b1140089b td {border: 1px solid white;}</style><table id="blocksb3843c74-ad10-4f63-a305-364b1140089b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (7, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(7, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (46, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(46, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (165, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(165, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (238, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(238, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (59, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(59, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (241, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(241, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (250, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(250, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (99, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(99, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (45, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(45, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (61, 0, 0)" style="w ...

# %% [markdown]
# It's interesting to watch one or two steps explicitly to see that it's doing what we expect, then to run things for a while.

# %%
one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks47185fe4-347b-4cc2-999e-58ee67d91ea1 td {border: 1px solid white;}</style><table id="blocks47185fe4-347b-4cc2-999e-58ee67d91ea1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (113, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(113, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (164, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(164, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (176, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(176, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (158, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(158, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (196, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(196, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (184, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(184, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (171, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(171, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (141, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(141, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (115, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(115, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (164, 0, ...

# %%
one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8f55789b-557c-4f8b-bcb2-072f7345d825 td {border: 1px solid white;}</style><table id="blocks8f55789b-557c-4f8b-bcb2-072f7345d825" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (123, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(123, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (160, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(160, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (173, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(173, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (175, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(175, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (174, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(174, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (180, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(180, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (172, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(172, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (155, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(155, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (157, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(157, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (165, 0, ...

# %%
one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb83bac03-546e-49e2-a1b2-890f9d6b0bf5 td {border: 1px solid white;}</style><table id="blocksb83bac03-546e-49e2-a1b2-890f9d6b0bf5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (113, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(113, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (158, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(158, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (170, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(170, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (172, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(172, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (176, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(176, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (176, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(176, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (169, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(169, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (163, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(163, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (167, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(167, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (164, 0, ...

# %% [markdown]
# Seems to be working ...

# %%
for i in range(500):
    one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks26b36211-76ce-4f80-bfcc-1e2631c3d2e5 td {border: 1px solid white;}</style><table id="blocks26b36211-76ce-4f80-bfcc-1e2631c3d2e5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (101, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(101, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (142, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(142, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (161, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(161, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (171, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(171, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (177, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(177, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (181, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(181, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (183, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(183, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (185, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(185, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (186, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(186, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (186, 0, ...

# %% [markdown]
# And, as promised, it looks like we're converging to the same solution. This sort of thing makes it easy to plug in different boundary conditions and examine the result. We can try all sorts of strange things. Here's an example:

# %%
for block in grid:
    if block.row == 0:
        block.red = block.col * 10
    elif block.row == 19:
        block.red = (19 - block.col) * 10
    elif block.col in (0,19):
        if divmod(block.row,2)[1] == 0:
            block.red = 200
        else:
            block.red = 0
    else:
        block.red = 0
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9706636f-3d26-4093-a0a8-2e60d3f23345 td {border: 1px solid white;}</style><table id="blocks9706636f-3d26-4093-a0a8-2e60d3f23345" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (10, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(10, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (20, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(20, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (30, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(30, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (40, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(40, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (50, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(50, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (60, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(60, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (70, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(70, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (80, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(80, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (90, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(90, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (100, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(100, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (110, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(110, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (120, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(120, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (130, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(130, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (140, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(140, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (150, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(150, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (160, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(160, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (170, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(170, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (180, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(180, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (190, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(190, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb( ...

# %%
one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8b64bdea-1351-42c0-aba0-bb2fe7362ab7 td {border: 1px solid white;}</style><table id="blocks8b64bdea-1351-42c0-aba0-bb2fe7362ab7" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (10, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(10, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (20, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(20, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (30, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(30, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (40, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(40, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (50, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(50, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (60, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(60, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (70, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(70, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (80, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(80, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (90, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(90, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (100, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(100, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (110, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(110, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (120, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(120, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (130, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(130, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (140, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(140, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (150, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(150, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (160, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(160, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (170, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(170, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (180, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(180, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (190, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(190, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (3, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(3, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (6, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(6, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (9, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(9, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (12, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(12, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (16, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(16, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (19, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(19, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (22, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(22, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (26, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(26, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (29, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(29, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (32, 0, 0)" style="width: 20px; height: 20px;backgroun ...

# %%
one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9fa10e77-29e4-4190-b443-b5f66fa555a2 td {border: 1px solid white;}</style><table id="blocks9fa10e77-29e4-4190-b443-b5f66fa555a2" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (10, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(10, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (20, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(20, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (30, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(30, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (40, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(40, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (50, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(50, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (60, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(60, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (70, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(70, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (80, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(80, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (90, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(90, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (100, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(100, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (110, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(110, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (120, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(120, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (130, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(130, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (140, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(140, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (150, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(150, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (160, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(160, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (170, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(170, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (180, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(180, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (190, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(190, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (17, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(17, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (15, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(15, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (16, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(16, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (19, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(19, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (23, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(23, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (28, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(28, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (33, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(33, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (38, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(38, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (42, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(42, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (47, 0, 0)" style="width: 20px; height: 20px;bac ...

# %%
for i in range(500):
    one_step()
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks90c310e3-35e6-463f-be1b-2cf27c5a0f76 td {border: 1px solid white;}</style><table id="blocks90c310e3-35e6-463f-be1b-2cf27c5a0f76" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (10, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(10, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (20, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(20, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (30, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(30, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (40, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(40, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (50, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(50, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (60, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(60, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (70, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(70, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (80, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(80, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (90, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(90, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (100, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(100, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (110, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(110, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (120, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(120, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (130, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(130, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (140, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(140, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (150, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(150, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (160, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(160, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (170, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(170, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (180, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(180, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (190, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(190, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (37, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(37, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (43, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(43, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (47, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(47, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (53, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(53, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (60, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(60, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (67, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(67, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (75, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(75, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (83, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(83, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (91, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(91, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (99, 0, 0)" style="width: 20px; height: 20px;bac ...

# %% [markdown]
# Not bad! One simple function (`one_step`) allowed us to solve all sorts of setups that would have been quite tough to handle analytically! The disadvantage is that we're approximating things, so we care about how many blocks we've divvied our grid up into, etc. If we want to handle more complicated systems, we'll have to switch to `numpy` and `imshow` instead of `ipythonblocks`.
#
# ## Switching to numpy and matplotlib and imshow
#
# Here, `T` will be a `numpy` array describing our temperature.
#
# For fun, we'll make the left boundary 100, but the right boundary part of a `sin` function. The `interpolation='none'` part of `imshow` tells it to show each member of the array like a square. Telling it something else like `interpolation='nearest'` or `'gaussian'` will smooth the picture out. That looks better, but it's a little harder to see exactly what's going on with our algorithm.
#
# Note here that the default colormap for `imshow` has red as hot and blue as cold. Before, we were using black as cold. Here, we get more colors.

# %%
nx, ny = 20,20
T = np.zeros((nx,ny))
T[:,0] = 100 # Left boundary
T[:,-1] = 100*np.sin(np.arange(0,nx)/nx) # Right boundary
T[0,:] = 0 # Top boundary
T[-1,:] = 0 # Bottom boundary
plt.imshow(T,interpolation='none')

# %% [markdown]
# How will we know that we're done? We'll calculate how much the error changed between iterations. We'll do this by saving the previous step in `TN` and subtracting. We'll say that we've converged when the maximum error is lower than some threshold `epsilon`. We don't want to run forever, so we'll set a maximum number of iterations.

# %%
# We modify T in place. If you hate side effects, 
# make a copy of T at the beginning, 
# and change the return statements to return T
def solveLaplace(T,epsilon=1e-1,maxiter=1000):
    TN = T.copy()
    for i in range(maxiter):
        # We'll be a bit clever with numpy indexing here
        T[1:-1,1:-1] = (T[0:-2,1:-1]+T[2:,1:-1]+T[1:-1,0:-2]+T[1:-1,2:])/4.
        err = np.abs(TN - T)
        
        if np.max(err) < epsilon:
            print "Reached convergence after",i+1,"iterations"
            print "(max error: %g)"%(np.max(err))
            return
        TN = T.copy()
    print "No convergence after",i+1,"iterations"
    print "(max error: %g)"%(np.max(err))
    return

# %%
solveLaplace(T,maxiter=1000)
plt.imshow(T,interpolation='None')
# Out:
# Reached convergence after 153 iterations
# (max error: 0.0986651)

# %% [markdown]
# ## Animating it
#
# We can make some fun animations using Jake Vanderplas's [JSAnimation](https://github.com/jakevdp/JSAnimation):

# %%
from JSAnimation import IPython_display
from matplotlib import animation

# %% [markdown]
# Here, we're just going to chunk through a given number of frames and show the result. So, we'll get rid of the convergence testing. As with my last notebook, we'll use a "fragile" version, where we completely ignore the fact that the animator asks us to return results for a given value; instead, we'll just update T each time, ignoring that argument.
#
# This time, the "fragile" business means we have to specifically not do anything the 1st time through, so that our first frame is the initial conditions.

# %%
fig = plt.figure()
ax = plt.gca()
T = np.zeros((nx,ny))
T[:,0] = 100 # Left boundary
T[:,-1] = 100*np.sin(np.arange(0,nx)/nx) # Right boundary
T[0,:] = 0 # Top boundary
T[-1,:] = 0 # Bottom boundary

def init():
    img = ax.imshow(T,interpolation='None')
    return img,
def updateLaplace_fragile(i):
    # Don't do anything the 1st time through, so that we plot the initial conditions
    if i != 0:
        T[1:-1,1:-1] = (T[0:-2,1:-1]+T[2:,1:-1]+T[1:-1,0:-2]+T[1:-1,2:])/4.
    img = ax.imshow(T,interpolation='None')
    return img,
animation.FuncAnimation(fig, updateLaplace_fragile, init_func=init,
                        frames=150, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgBRTRRZZLNHCJXBGG">
#     <br>
#     <input id="_anim_sliderBRTRRZZLNHCJXBGG" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animBRTRRZZLNHCJXBGG.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animBRTRRZZLNHCJXBGG.slower()">&#8211;</button>
#     <button onclick="animBRTRRZZLNHCJXBGG.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBRTRRZZLNHCJXBGG.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBRTRRZZLNHCJXBGG.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBRTRRZZLNHCJXBGG.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animBRTRRZZLNHCJXBGG.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBRTRRZZLNHCJXBGG.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBRTRRZZLNHCJXBGG.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBRTRRZZLNHCJXBGG.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectBRTRRZZLNHCJXBGG" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgBRTRRZZLNHCJXBGG";
#     var slider_id = "_anim_sliderBRTRRZZLNHCJXBGG";
#     var loop_select_id = "_anim_loop_selectBRTRRZZLNHCJXBGG";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# So that's pretty neat. We can also try it out with random starting values

# %%
fig = plt.figure()
ax = plt.gca()
T = np.random.rand(nx,ny)*100
T[:,0] = 100 # Left boundary
T[:,-1] = 100*np.sin(np.arange(0,nx)/nx) # Right boundary
T[0,:] = 0 # Top boundary
T[-1,:] = 0 # Bottom boundary
animation.FuncAnimation(fig, updateLaplace_fragile, init_func=init,
                        frames=150, blit=True)

# %% [markdown]
# Which brings up an interesting point that you may have noticed if you played around with the random values in the `ipythonblocks` portion above: this can converge faster. Random initial conditions can actually be closer to our final value than setting everything equal to zero.

# %% [markdown]
# We can also try less random initial conditions

# %%
import matplotlib.image as mpimg
import urllib2
fig = plt.figure()
ax = plt.gca()
im = mpimg.imread(urllib2.urlopen('http://mglerner.com/img/mgl_personal_small.png'))
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])
T = rgb2gray(im)*100
nx,ny = T.shape
T[:,0] = 100 # Left boundary
T[:,-1] = 100*np.sin(4*np.arange(0,nx)/nx) # Right boundary
T[0,:] = 0 # Top boundary
T[-1,:] = 0 # Bottom boundary
animation.FuncAnimation(fig, updateLaplace_fragile, init_func=init,
                        frames=500, blit=True)
