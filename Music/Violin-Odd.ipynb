# %% [markdown]
# # The Bowed String
#
# Mostly taken from

# %%
from __future__ import division
import numpy as np
from numpy import pi, sin, cos, array, linspace, zeros_like
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot
# %matplotlib inline
from JSAnimation import IPython_display
from matplotlib import animation

# %%
c = 1.0 # wave speed
l = 2.0 # distance from nut to bridge
x0 = 0.2 # bow location
x0_array = array((x0,))
alpha = x0/c
A = 1.0 # maximum amplitude at x0

Npoints = 100
x = linspace(0,l,Npoints)

# %%
def b(n):
    return ((2*A*l*l)/(n*n*pi*pi*c*alpha*(l-c*alpha))) * sin(n*pi*c*alpha/l)

# %%
ns = array(range(1,11))
plot(ns,b(ns),'bo')

# %%
def y(t,N,x=x):
    result = zeros_like(x)
    for n in range(1,N+1):
        result = result + b(n)*(sin(n*pi*x/l)*cos(n*pi*c*t/l)) / (sin(n*pi*x0/l))
    return result

# %%
plot(x,y(0,1))

# %%
plot(x,y(0,2))

# %%
plot(x,y(0,5))

# %%
plot(x,y(0,15))

# %%
plot(x,y(1.0,1))

# %%
plot(x,y(1.0,2))

# %%
plot(x,y(1.0,3))

# %%
plot(x,y(1.0,10))

# %%
plot(x,y(1.0,100))

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0, l), ylim=(-3, 3))
line, = ax.plot([], [], lw=2, color='blue')
point, = ax.plot([], [], lw=5, color='black', marker='o')

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    point.set_data([], [])
    return line,point

def animate(t,N=100):
    line.set_data(x,y(t/10.0,N))
    point.set_data(x0_array,y(t/10.0,N,x=x0_array))
    return line,point

animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100,)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
x0 = 0.75 # bow location
x0_array = array((x0,))
alpha = x0/c

fig = plt.figure()
ax = plt.axes(xlim=(0, l), ylim=(-3, 3))
line, = ax.plot([], [], lw=2, color='blue')
point, = ax.plot([], [], lw=5, color='black', marker='o')
animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100,)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
x0 = 1.0 # bow location
x0_array = array((x0,))
alpha = x0/c

fig = plt.figure()
ax = plt.axes(xlim=(0, l), ylim=(-3, 3))
line, = ax.plot([], [], lw=2, color='blue')
point, = ax.plot([], [], lw=5, color='black', marker='o')
animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100,)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
x0 = 0.1 # bow location
x0_array = array((x0,))
alpha = x0/c

fig = plt.figure()
ax = plt.axes(xlim=(0, l), ylim=(-6, 6))
line, = ax.plot([], [], lw=2, color='blue')
point, = ax.plot([], [], lw=5, color='black', marker='o')
animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100,)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
# sum over odd n 1.312/(pi^2*n^2)*cos(880n*pi*t)
N = 100
t = linspace(0,.01,1000)
result = zeros_like(t)
for n in range(N):
    n = 2*n + 1
    result = result + 1.312*cos(880*n*pi*t)/(pi*pi*n*n)
plot(t,result,'-')

# %%
# sum over odd n 1.312/(pi^2*n^2)*cos(880n*pi*t)
N = 100
t = linspace(0,.0001,10000)
result = zeros_like(t)
for n in range(N):
    n = 2*n + 1
    result = result + 1.312/(pi*pi*n*n*cos(880*n*pi*t))
plot(t,result,'-')
